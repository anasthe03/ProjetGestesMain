# %%
import os

# Structure du projet
folders = [
    'data/raw',           # Données brutes
    'data/processed',     # Données prétraitées
    'data/augmented',     # Données augmentées
    'models',             # Modèles sauvegardés
    'notebooks',          # Vos notebooks Jupyter
    'src',                # Scripts Python
    'results/plots',      # Graphiques et visualisations
    'results/metrics',    # Métriques d'évaluation
    'logs'                # Logs d'entraînement
]

for folder in folders:
    os.makedirs(folder, exist_ok=True)
    print(f"✅ Dossier créé : {folder}")
# Out:
# ✅ Dossier créé : data/raw
# ✅ Dossier créé : data/processed
# ✅ Dossier créé : data/augmented
# ✅ Dossier créé : models
# ✅ Dossier créé : notebooks
# ✅ Dossier créé : src
# ✅ Dossier créé : results/plots
# ✅ Dossier créé : results/metrics
# ✅ Dossier créé : logs
