# %%
import cv2
import numpy as np
import tensorflow as tf
import mediapipe as mp
import matplotlib.pyplot as plt

print("OpenCV version:", cv2.__version__)
print("TensorFlow version:", tf.__version__)
print("NumPy version:", np.__version__)
print("✅ Toutes les bibliothèques sont installées correctement!")
# Out:
# C:\Users\N-ESS\anaconda3\envs\gesture_recognition\lib\site-packages\h5py\__init__.py:36: UserWarning: h5py is running against HDF5 1.14.5 when it was built against 1.14.6, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# OpenCV version: 4.12.0
# TensorFlow version: 2.20.0
# NumPy version: 1.26.4
# ✅ Toutes les bibliothèques sont installées correctement!

# %%
#  verifier le chemin
import os

# Afficher le dossier de travail actuel
dossier_actuel = os.getcwd()
print(f"📍 Vous êtes ici : {dossier_actuel}")

# Lister ce qui se trouve dans ce dossier
print(f"\n📂 Contenu de ce dossier :")
for item in os.listdir(dossier_actuel):
    if os.path.isdir(item):
        print(f"  📁 {item}/")
    else:
        print(f"  📄 {item}")
# Out:
# 📍 Vous êtes ici : C:\Users\N-ESS\Documents\ProjetGestesMain
#
# 📂 Contenu de ce dossier :
#   📁 .ipynb_checkpoints/
#   📄 test.ipynb
